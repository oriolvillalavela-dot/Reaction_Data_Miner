# %% [markdown]
# # SURF Extractor Pipeline Demonstration
#
# This notebook acts as an interactive demonstration of the Multi-Agent extraction pipeline.
# We instantiate the overarching `CoordinatorAgent`, simulate PDF parsing,
# and observe how the extraction and criticism agents interface.

# %%
from surf_extractor.agents.coordinator import CoordinatorAgent

print("Initializing the agent orchestration layer...")
coordinator = CoordinatorAgent()
